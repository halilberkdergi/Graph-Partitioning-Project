# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas import json_normalize



import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'BAXJ4D2EUQZ1H0PORU3ZNYROWJ4NHTD4ZWXC4JTR0503O3Q1' # your Foursquare ID
CLIENT_SECRET = 'LTTP3N0W0SHVZ4ZFIUWCAE4NGDQX4LEUAGZOMXOOWD5PZPY1' # your Foursquare Secret
ACCESS_TOKEN = 'UCO4AEGWBQA1ZRB5KVFXMLOUDU1IESDXRGI0GCIGKZ1UZQIR' # your FourSquare Access Token
VERSION = '20210227'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BAXJ4D2EUQZ1H0PORU3ZNYROWJ4NHTD4ZWXC4JTR0503O3Q1
# CLIENT_SECRET:LTTP3N0W0SHVZ4ZFIUWCAE4NGDQX4LEUAGZOMXOOWD5PZPY1

# %%
address = 'ankara'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.9207893 32.8540412

# %%
search_query = 'Orta Doğu'
radius=10000
print(search_query + ' .... OK')
# Out:
# Orta Doğu .... OK

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=BAXJ4D2EUQZ1H0PORU3ZNYROWJ4NHTD4ZWXC4JTR0503O3Q1&client_secret=LTTP3N0W0SHVZ4ZFIUWCAE4NGDQX4LEUAGZOMXOOWD5PZPY1&ll=39.9207893,32.8540412&oauth_token=UCO4AEGWBQA1ZRB5KVFXMLOUDU1IESDXRGI0GCIGKZ1UZQIR&v=20210227&query=Orta Doğu&radius=10000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6064bced3f40915267c10b21'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4bed1e076e8c20a191e76f61',
#     'name': 'Middle East Technical University (Orta Doğu Teknik Üniversitesi)',
#     'location': {'address': 'Üniversiteler Mah. Dumlupınar Blv. No:1',
#      'lat': 39.900058812442516,
#      'lng': 32.78871443373877,
#      'distance': 6036,
#      'postalCode': '06800',
#      'cc': 'TR',
#      'city': 'Çankaya',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Üniversiteler Mah. Dumlupınar Blv. No:1',
#       '06800 Çankaya']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '38555090'},
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '57c44b16498e8d0a75c75af1',
#     'name': 'Orta Doğu Temel Lisesi',
#     'location': {'lat': 39.920162,
#      'lng': 32.853085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.920162,
#        'lng': 32.853085}],
#      'distance': 107,
#      'postalCode': '06420',
#      'cc': 'TR',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['06420']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '50c60741e4b07819230fcdc7',
#     'name': 'Orta Doğu Engelsiz Eğitim Derneği',
#     'location': {'lat': 39.919028394741375,
#      'lng': 32.85953147968068,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.919028394741375,
#        'lng': 32.85953147968068}],
#      'distance': 508,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '53550f03498ea16e038b3160',
#     'name': 'Gazi Üniversitesi Orta Doğu ve Orta Asya Araştırmaları Merkezi',
#     'location': {'lat': 39.92877124637859,
#      'lng': 32.845432590599344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92877124637859,
#        'lng': 32.845432590599344}],
#      'distance': 1153,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5ab6417db3c96171499a6f3f',
#     'name': 'Orta Dogu Testoranı',
#     'location': {'lat': 39.905231,
#      'lng': 32.860701,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.905231,
#        'lng': 32.860701}],
#      'distance': 1822,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '56bc5cf9498e63a7bf6515dc',
#     'name': 'Orta Doğu Teknik Üniversitesi ODTÜ',
#     'location': {'address': 'ODTÜ Fen bilimleri Ana Bilim Dalı',
#      'lat': 39.921454350465304,
#      'lng': 32.822743633205064,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.921454350465304,
#        'lng': 32.822743633205064}],
#      'distance': 2673,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['ODTÜ Fen bilimleri Ana Bilim Dalı', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1af941735',
#       'name': 'College Auditorium',
#       'pluralName': 'College Auditoriums',
#       'shortName': 'Auditorium',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/auditorium_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5a1e880b1213845819cdcea4',
#     'name': 'Orta Doğu Yapı Deneti̇m A.Ş.',
#     'location': {'address': 'Şefkat mah.',
#      'crossStreet': 'cumhuriyet cad.',
#      'lat': 39.97805,
#      'lng': 32.86946,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.97805,
#        'lng': 32.86946}],
#      'distance': 6508,
#      'cc': 'TR',
#      'city': 'Keçiören',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Şefkat mah. (cumhuriyet cad.)', 'Keçiören']},
#     'categories': [{'id': '5454144b498ec1f095bff2f2',
#       'name': 'Construction & Landscaping',
#       'pluralName': 'Construction & Landscaping',
#       'shortName': 'Construction',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '53b571d4498e69be2ee0bdcf',
#     'name': 'Orta Doğu teknik Üniversitesi Rektörlük Binası',
#     'location': {'lat': 39.91464985642421,
#      'lng': 32.887767260925386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91464985642421,
#        'lng': 32.887767260925386}],
#      'distance': 2959,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '57c7c378498ed6c25b2704a0',
#     'name': 'Orta Doğulular Eğitim Kurumları',
#     'location': {'address': 'Numara 34',
#      'crossStreet': 'Sakarya Caddesi',
#      'lat': 39.916116979825816,
#      'lng': 32.854361040364765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.916116979825816,
#        'lng': 32.854361040364765}],
#      'distance': 520,
#      'cc': 'TR',
#      'city': 'Kızılay',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Numara 34 (Sakarya Caddesi)', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'shortName': 'High School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '56dff69f498e1ac3f9301389',
#     'name': 'Orta Doğu Teknik Üniversitesi ODTÜ',
#     'location': {'address': 'Orta Doğu Teknik Üniversitesi ODTÜ',
#      'crossStreet': 'Dumlu Pınar Bul',
#      'lat': 39.88593376018345,
#      'lng': 32.87169011072692,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.88593376018345,
#        'lng': 32.87169011072692}],
#      'distance': 4162,
#      'cc': 'TR',
#      'city': 'Çankaya',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Orta Doğu Teknik Üniversitesi ODTÜ (Dumlu Pınar Bul)',
#       'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d19b941735',
#       'name': 'College Science Building',
#       'pluralName': 'College Science Buildings',
#       'shortName': 'Science',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_science_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '57977a02498e7369864e785a',
#     'name': 'Orta doğu teknik üniversitesi',
#     'location': {'lat': 39.912187,
#      'lng': 32.809362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.912187,
#        'lng': 32.809362}],
#      'distance': 3933,
#      'postalCode': '06560',
#      'cc': 'TR',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['06560']},
#     'categories': [{'id': '4bf58dd8d48988d1a2941735',
#       'name': 'Community College',
#       'pluralName': 'Community Colleges',
#       'shortName': 'Community College',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/communitycollege_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '519b3636498e055d7e103085',
#     'name': 'Orta Doğu Ihracaatcılar Birliği',
#     'location': {'address': 'Ceyhun Atıf Kansu Cad. No:120',
#      'lat': 39.8908576965332,
#      'lng': 32.81560516357422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.8908576965332,
#        'lng': 32.81560516357422}],
#      'distance': 4677,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ceyhun Atıf Kansu Cad. No:120', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5241aecf498e2cf887cac1a0',
#     'name': 'Orta Dogu TEMIZLIK',
#     'location': {'lat': 39.87398910522461,
#      'lng': 32.86027526855469,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.87398910522461,
#        'lng': 32.86027526855469}],
#      'distance': 5236,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '599ecb57c0f1635ccfb7dea6',
#     'name': 'Orta Doğu Restoran',
#     'location': {'lat': 39.95503,
#      'lng': 32.903027,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.95503,
#        'lng': 32.903027}],
#      'distance': 5657,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '4e132e46d4c07597ff8fbef1',
#     'name': 'Orta Dogu Camlik Sitesi',
#     'location': {'lat': 39.88829033466404,
#      'lng': 32.79201536967533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.88829033466404,
#        'lng': 32.79201536967533}],
#      'distance': 6414,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '56bc49a5498ea92e5d4d6a4c',
#     'name': 'Orta Doğu Teknik Üniversitesi Fen Bilimleri Kampüs Cafe',
#     'location': {'address': 'Ankara',
#      'crossStreet': 'Doğu Caddesi',
#      'lat': 39.90625749710913,
#      'lng': 32.78410727186332,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.90625749710913,
#        'lng': 32.78410727186332}],
#      'distance': 6186,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara (Doğu Caddesi)', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '55f828ab498e2e2c8ef9ceb8',
#     'name': 'Orta Doğu Emlak&Otomotiv',
#     'location': {'address': '929.Cadde',
#      'crossStreet': 'Dikmen caddesi',
#      'lat': 39.86699944703867,
#      'lng': 32.82921648185324,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.86699944703867,
#        'lng': 32.82921648185324}],
#      'distance': 6352,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Dikmen',
#      'country': 'Türkiye',
#      'formattedAddress': ['929.Cadde (Dikmen caddesi)', 'Ankara']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5de66f7b242f6b00082ee629',
#     'name': 'orta dogu teknik',
#     'location': {'lat': 39.890113,
#      'lng': 32.790284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.890113,
#        'lng': 32.790284}],
#      'distance': 6426,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '4e3e8eb045dd68e32747dd4b',
#     'name': 'Orta Dogu Camlik Sitesi Playground',
#     'location': {'lat': 39.87975646464119,
#      'lng': 32.795668868030816,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.87975646464119,
#        'lng': 32.795668868030816}],
#      'distance': 6761,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1e7941735',
#       'name': 'Playground',
#       'pluralName': 'Playgrounds',
#       'shortName': 'Playground',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5331592d498e8ae4fcbedc6a',
#     'name': 'Orta Doğu Teknik Üniversitesi Spor Salonu',
#     'location': {'lat': 39.89269782434548,
#      'lng': 32.776215092548036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.89269782434548,
#        'lng': 32.776215092548036}],
#      'distance': 7344,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5716f9d9498e15f35f13d955',
#     'name': 'orta doğu eğitim kurumları',
#     'location': {'address': 'Atatürk Bulvarı Meşrutiyet Caddesi Çankaya',
#      'crossStreet': 'Meşrutiyet',
#      'lat': 39.99444371881475,
#      'lng': 32.87398071089533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.99444371881475,
#        'lng': 32.87398071089533}],
#      'distance': 8373,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Atatürk Bulvarı Meşrutiyet Caddesi Çankaya (Meşrutiyet)',
#       'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5cf3cc4c535d6f002c6bbfae',
#     'name': 'Ankara Orta Doğu Teknik Üniversitesi',
#     'location': {'lat': 39.890109,
#      'lng': 32.780233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.890109,
#        'lng': 32.780233}],
#      'distance': 7168,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1a2941735',
#       'name': 'Community College',
#       'pluralName': 'Community Colleges',
#       'shortName': 'Community College',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/communitycollege_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '542d4896498ef9b2380c5f46',
#     'name': 'OrtaDogu ENERJI',
#     'location': {'lat': 39.932766,
#      'lng': 32.836271,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.932766,
#        'lng': 32.836271}],
#      'distance': 2019,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '542d4912498e1c806a8e244b',
#     'name': 'OrtaDogu Enerji Ofis',
#     'location': {'address': 'Mebusevleri Mah. Şerefli Sok. 5/7 Tandoğan',
#      'crossStreet': 'Dögol, Anıt, Gençlik',
#      'lat': 39.932839,
#      'lng': 32.836204,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.932839,
#        'lng': 32.836204}],
#      'distance': 2029,
#      'cc': 'TR',
#      'neighborhood': 'Mebusevleri',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Mebusevleri Mah. Şerefli Sok. 5/7 Tandoğan (Dögol, Anıt, Gençlik)',
#       'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '55d4a775498eb5582068fdb5',
#     'name': 'Orta Dünya',
#     'location': {'address': 'Hatay Sokak 15/B',
#      'lat': 39.91804922529962,
#      'lng': 32.85844390230781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91804922529962,
#        'lng': 32.85844390230781}],
#      'distance': 484,
#      'cc': 'TR',
#      'neighborhood': 'Çankaya',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Hatay Sokak 15/B', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5200ef2b498e32d1da32fd5f',
#     'name': 'ORTADOĞU GAZETESİ ANKARA TEMSİLCİLİĞİ',
#     'location': {'address': 'Atatürk Bulvarı 223/15',
#      'lat': 39.905247556787636,
#      'lng': 32.85831438863879,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.905247556787636,
#        'lng': 32.85831438863879}],
#      'distance': 1768,
#      'cc': 'TR',
#      'country': 'Türkiye',
#      'formattedAddress': ['Atatürk Bulvarı 223/15']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '4ec25ae1d3e3700a5ca70fa4',
#     'name': 'Ortadoğu Dershanesi',
#     'location': {'address': 'Kızılay',
#      'lat': 39.91878146857837,
#      'lng': 32.854729239355486,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91878146857837,
#        'lng': 32.854729239355486}],
#      'distance': 231,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Kızılay', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '4dd385ddc65b69f9362d5af6',
#     'name': 'Özel Ortadoğu 19 Mayıs Hastanesi',
#     'location': {'address': 'Nacı Çakır Mah. 761. Sok. No: 2 Dikmen',
#      'lat': 39.87527461536749,
#      'lng': 32.840642581290545,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.87527461536749,
#        'lng': 32.840642581290545}],
#      'distance': 5194,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Nacı Çakır Mah. 761. Sok. No: 2 Dikmen', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5460fb71498e179a94c507e3',
#     'name': 'Orta Bahçe',
#     'location': {'address': 'Selanik 2 Cad. Kızılay',
#      'lat': 39.91631816590085,
#      'lng': 32.85819333879417,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91631816590085,
#        'lng': 32.85819333879417}],
#      'distance': 611,
#      'cc': 'TR',
#      'country': 'Türkiye',
#      'formattedAddress': ['Selanik 2 Cad. Kızılay']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5a0aa9be805e3f5d48c26dae',
#     'name': 'Emine Doğu Mali Müşavirlik Ve Sigorta Ofisi',
#     'location': {'crossStreet': 'Atatürk Bulvarı',
#      'lat': 39.919802,
#      'lng': 32.854323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.919802,
#        'lng': 32.854323}],
#      'distance': 112,
#      'cc': 'TR',
#      'city': 'Kızılay',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Atatürk Bulvarı', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5d506afdff5ff10008265e96',
#     'name': 'Orta Asya Mutfağı',
#     'location': {'address': 'Ankara Kızılay',
#      'lat': 39.921905,
#      'lng': 32.857817,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.921905,
#        'lng': 32.857817}],
#      'distance': 345,
#      'cc': 'TR',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara Kızılay']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '50599fbfe4b05ea416541887',
#     'name': 'Milli Egitim Bakanligi Orta Ogretim Genel Mudurlugu',
#     'location': {'lat': 39.91974621696552,
#      'lng': 32.852977921950945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91974621696552,
#        'lng': 32.852977921950945}],
#      'distance': 147,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '4d54ecf3cff7721e2defa3f5',
#     'name': 'TODAİE',
#     'location': {'address': '85.Cad .',
#      'crossStreet': '85. Cad.',
#      'lat': 39.91781120964686,
#      'lng': 32.84309177099368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91781120964686,
#        'lng': 32.84309177099368}],
#      'distance': 991,
#      'postalCode': '06100',
#      'cc': 'TR',
#      'neighborhood': 'Yücetepe',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['85.Cad . (85. Cad.)', '06100 Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '54225f59498eb4329db674f3',
#     'name': 'Güneş Sigorta Orta Anadolu Bölge Müdürlüğü',
#     'location': {'address': 'Atatürk Bulvarı NO 97 Kat :2',
#      'lat': 39.91981691093127,
#      'lng': 32.85413921600813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91981691093127,
#        'lng': 32.85413921600813}],
#      'distance': 108,
#      'cc': 'TR',
#      'city': 'Çankaya',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Atatürk Bulvarı NO 97 Kat :2', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '55aa53d7498e675071cd65a1',
#     'name': 'Orta Bahçe Pub',
#     'location': {'lat': 39.91632547624298,
#      'lng': 32.85809961369904,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91632547624298,
#        'lng': 32.85809961369904}],
#      'distance': 605,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'shortName': 'Beer Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '531c426e11d203668514b242',
#     'name': 'Ortadoğu Akvaryum',
#     'location': {'address': 'Bosna Hersek Caddesi',
#      'lat': 39.91648222770369,
#      'lng': 32.81879446238354,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91648222770369,
#        'lng': 32.81879446238354}],
#      'distance': 3047,
#      'cc': 'TR',
#      'city': 'Emek',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Bosna Hersek Caddesi', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d100951735',
#       'name': 'Pet Store',
#       'pluralName': 'Pet Stores',
#       'shortName': 'Pet Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5e42e069dca0ae00088264c7',
#     'name': 'Orta Asya Uygur Lokantası',
#     'location': {'lat': 39.923988,
#      'lng': 32.848352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.923988,
#        'lng': 32.848352}],
#      'distance': 602,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara']},
#     'categories': [{'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'shortName': 'Theme Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '526f89d711d2c8321b3eba54',
#     'name': 'Dogu Mobilya',
#     'location': {'address': 'Fevzi Cakmak 2 Sk. No: 28/A',
#      'crossStreet': 'GMK Bulvari',
#      'lat': 39.9208,
#      'lng': 32.8509,
#      'labeledLatLngs': [{'label': 'display', 'lat': 39.9208, 'lng': 32.8509}],
#      'distance': 268,
#      'postalCode': '06000',
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Fevzi Cakmak 2 Sk. No: 28/A (GMK Bulvari)',
#       '06000 Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '532ef92a498e58f23ba0a24b',
#     'name': 'Orta Kahve',
#     'location': {'address': 'Bestekar Sokak 13 Numara',
#      'lat': 39.911592768490365,
#      'lng': 32.85749934285197,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.911592768490365,
#        'lng': 32.85749934285197}],
#      'distance': 1065,
#      'cc': 'TR',
#      'country': 'Türkiye',
#      'formattedAddress': ['Bestekar Sokak 13 Numara']},
#     'categories': [{'id': '4bf58dd8d48988d1e1931735',
#       'name': 'Arcade',
#       'pluralName': 'Arcades',
#       'shortName': 'Arcade',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/arcade_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '53243245498e16f1566b4114',
#     'name': 'Kuveyt Türk Orta Anadolu Bölge Futbol Turnuvası',
#     'location': {'lat': 39.92220082347285,
#      'lng': 32.851446871138315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92220082347285,
#        'lng': 32.851446871138315}],
#      'distance': 271,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '52a87e97498e6c7773ceba11',
#     'name': 'doğu muhasebe',
#     'location': {'lat': 39.92193483700744,
#      'lng': 32.85741673649242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92193483700744,
#        'lng': 32.85741673649242}],
#      'distance': 315,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '56e5356d498edbe68998c25d',
#     'name': 'Orta Asya',
#     'location': {'lat': 39.92343778904444,
#      'lng': 32.867708967741514,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92343778904444,
#        'lng': 32.867708967741514}],
#      'distance': 1203,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '52e81612bcbc57f1066b79e7',
#       'name': 'Circus',
#       'pluralName': 'Circuses',
#       'shortName': 'Circus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '57079a78498e6e5b91d83d47',
#     'name': 'Orta hopa mahallesi',
#     'location': {'lat': 39.919773,
#      'lng': 32.842026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.919773,
#        'lng': 32.842026}],
#      'distance': 1032,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '507ffd69e4b0324d29d37262',
#     'name': 'Ortadoğu Teknik İnsan Kaynakları ve Danışmanlık',
#     'location': {'lat': 39.88513223133081,
#      'lng': 32.85141382662005,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.88513223133081,
#        'lng': 32.85141382662005}],
#      'distance': 3975,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d125941735',
#       'name': 'Tech Startup',
#       'pluralName': 'Tech Startups',
#       'shortName': 'Tech Startup',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5662cf7d498ef0856f12b0ad',
#     'name': 'Özel Ortadoğu Hastanesi',
#     'location': {'address': 'İvedik Caddesi No:55',
#      'lat': 39.96378334097306,
#      'lng': 32.80052738683632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.96378334097306,
#        'lng': 32.80052738683632}],
#      'distance': 6615,
#      'postalCode': '06170',
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['İvedik Caddesi No:55', '06170 Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '51f8b050498e035ff5b2e0e9',
#     'name': 'Adnan Otuken Orta Bahce',
#     'location': {'lat': 39.919693357636504,
#      'lng': 32.85047205330064,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.919693357636504,
#        'lng': 32.85047205330064}],
#      'distance': 328,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5172c06fe4b0c790d5db6f22',
#     'name': 'Doğu Ekspresi',
#     'location': {'address': 'Ankara Garı',
#      'crossStreet': 'Doğu Ekspresi | Ankara - Kars Hattı',
#      'lat': 39.93514115816782,
#      'lng': 32.84339189529419,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.93514115816782,
#        'lng': 32.84339189529419}],
#      'distance': 1838,
#      'cc': 'TR',
#      'city': 'Çankaya',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara Garı (Doğu Ekspresi | Ankara - Kars Hattı)',
#       'Çankaya']},
#     'categories': [{'id': '4bf58dd8d48988d12a951735',
#       'name': 'Train',
#       'pluralName': 'Trains',
#       'shortName': 'Train',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5155da12e4b04f2130bc8e25',
#     'name': 'Ankara Orta Oyuncuları Tiyatrosu',
#     'location': {'address': 'Necatibey',
#      'lat': 39.92207680828038,
#      'lng': 32.8592285537779,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92207680828038,
#        'lng': 32.8592285537779}],
#      'distance': 465,
#      'cc': 'TR',
#      'city': 'Çankaya',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Necatibey', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d137941735',
#       'name': 'Theater',
#       'pluralName': 'Theaters',
#       'shortName': 'Theater',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '5416a4b6498ecd3717ae0c97',
#     'name': 'GORAM l Gazi Üni. Ortadoğu ve Orta Asya Araştırmaları Merkezi',
#     'location': {'lat': 39.929049701543526,
#      'lng': 32.84657819547347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.929049701543526,
#        'lng': 32.84657819547347}],
#      'distance': 1118,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False},
#    {'id': '555cac15498eb6112e069a72',
#     'name': 'Fem Dershanesi 701 Numaralı Sınıf Orta İkinci Sıranın Sağı',
#     'location': {'lat': 39.92420196068728,
#      'lng': 32.85705326770656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92420196068728,
#        'lng': 32.85705326770656}],
#      'distance': 458,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4f4534884b9074f6e4fb0174',
#       'name': 'Funeral Home',
#       'pluralName': 'Funeral Homes',
#       'shortName': 'Funeral Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/funeralhome_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617214701',
#     'hasPerk': False}]}}

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                         Kuğulu Park
# 1                       Kuğulu Park Restaurant & Cafe
# 2                              Kugulu Park Alt Gecidi
# 3   304 Kırkkonaklar - Gop - Kuğulu Park - Kızılay...
# 4                             kuğulu Park Saat&Çakmak
# 5                        Tarihi Kuğulu Park Köftecisi
# 6                               Kuğulu Park Simitçisi
# 7    Kuğulu Park Otobüs Durağı -Polonya Büyükelciligi
# 8                                Kuğulu Park Eczanesi
# 9                                    Kugulu Park Taxi
# 10                                   Kuğulu Park Büfe
# 11                        Kugulu Park Mesrubat Bufesi
# 12                                   A212 Kuğulu Park
# 13                              Park Oran Kuğulu Park
# 14                                      Kugulu Park 2
# 15                                 Yıldız Kuğulu Park
# 16                                   Kuğuluoğlu Parkı
# 17                                          Güvenpark
# 18                                          Starbucks
# 19                                    Güven Park Cafe
# 20                                      Kuğulu Pasajı
# 21                        The Green Park Ankara Hotel
# 22                                Business Park Hotel
# 23                                  Kuğulu İş Merkezi
# 24                                       Gençlik Park
# 25                           Kuğulu Veteriner Kliniği
# 26                                      Gençlik Parkı
# 27                                       Maltepe Park
# 28                                          Anıt Park
# 29                                     Kuğulu Çankaya
# 30                                       Kuğulu Optik
# 31                                     Kurtuluş Parkı
# 32                                       Ördekli Park
# 33                                Big Park Giyim B-25
# 34                  Kuğulu Veteriner Kliniği Anıttepe
# 35                                 Life Park Güzellik
# 36                                           Cep Park
# 37                                               Mado
# 38                                               Park
# 39                 Kuğulu Veteriner Kliniği Nenehatun
# 40                                 Kuğulu Çocuk Parkı
# 41                   Seğmenler Park (Seğmenler Parkı)
# 42                              Kuğulu Sanat Galerisi
# 43                                   Park Vadi Evleri
# 44                                Kızıl Ay Güven Park
# 45                                       Kuğulu Plajı
# 46                                          park kafe
# 47                                    A4 Kahve Kuğulu
# 48                                  Kızılay PARK KAFE
# 49                             Kuğulu Vitamin Sandwiç
#
#                                   categories  \
# 0                                       Park
# 1                         Turkish Restaurant
# 2                                       Road
# 3                                   Bus Line
# 4                      General Entertainment
# 5                                 Steakhouse
# 6                                 Bagel Shop
# 7                                   Bus Stop
# 8                             Medical Center
# 9                                 Taxi Stand
# 10                         Food & Drink Shop
# 11                                Smoke Shop
# 12                      Other Great Outdoors
# 13                           Nature Preserve
# 14                                      Park
# 15                                      Park
# 16                                      Park
# 17                                      Park
# 18                               Coffee Shop
# 19                                      Café
# 20                           Business Center
# 21                                     Hotel
# 22                                     Hotel
# 23                           Business Center
# 24                             National Park
# 25                              Veterinarian
# 26                                      Park
# 27                             Shopping Mall
# 28                                      Park
# 29                          Botanical Garden
# 30                              Optical Shop
# 31                                      Park
# 32                                      Park
# 33                            Clothing Store
# 34                               Pet Service
# 35                   Health & Beauty Service
# 36                         Mobile Phone Shop
# 37                            Ice Cream Shop
# 38                                      Park
# 39                              Veterinarian
# 40                                Playground
# 41                                      Park
# 42                               Art Gallery
# 43  Residential Building (Apartment / Condo)
# 44                                      Park
# 45                                     Beach
# 46                                      Café
# 47                               Coffee Shop
# 48                                      Café
# 49                            Sandwich Place
#
#                                              address        lat        lng  \
# 0                                        Kavaklıdere  39.902004  32.860324
# 1   Atatürk Blv. No:241/A Kuğulupark İçi Kavaklıdere  39.902078  32.859962
# 2                              Atatürk Blv.  Kızılay  39.904157  32.858546
# 3                                                NaN  39.918720  32.854324
# 4                                        Kuğulu Park  39.902522  32.860314
# 5                                                NaN  39.902206  32.860572
# 6                                                NaN  39.902374  32.860554
# 7                                                NaN  39.901944  32.859460
# 8                          Binnaz Sokak, Kavaklıdere  39.901878  32.861690
# 9                                           canakaya  39.902550  32.860430
# 10                  Tunalıhilmi Caddesi, Kavaklıdere  39.902022  32.861586
# 11                                               NaN  39.902190  32.862742
# 12                              Tunalı Hilmi Caddesi  39.902365  32.860399
# 13                                  Park Oran Evleri  39.847220  32.835299
# 14                                               NaN  39.864287  32.858679
# 15                                               NaN  39.865407  32.861477
# 16                                               NaN  39.925037  32.831177
# 17                                      Kızılay Mah.  39.919611  32.853327
# 18                                       Kızılay AVM  39.921120  32.853457
# 19           Kızılay Mah. Milli Müdafaa Cad. No:10/2  39.919918  32.852193
# 20                                               NaN  39.902845  32.860668
# 21                                        1443.cadde  39.903191  32.811716
# 22                                    Necatibey Cad.  39.923923  32.849894
# 23                                               NaN  39.902509  32.860724
# 24                                      bilkent mah.  39.921356  32.853650
# 25                               Büklüm Sk. No:105/B  39.905165  32.864791
# 26                                Doğanbey Mah. Ulus  39.938047  32.854079
# 27                    Şehit Gönenç Cad. No:5 Maltepe  39.924235  32.846568
# 28                         Mareşal Fevzi Çakmak Cad.  39.921860  32.833992
# 29                                               NaN  39.901960  32.859848
# 30                    Tunalı Hilmi Caddesi 123/18-51  39.902652  32.860468
# 31                                     Fidanlık Mah.  39.926774  32.863598
# 32                             Süleymanbey Sk. No:12  39.927288  32.842779
# 33                      Ankara kızılay metro çarşısı  39.921638  32.853998
# 34                            Gençlik Caddesi 24 / B  39.922842  32.842899
# 35                                               NaN  39.917728  32.855388
# 36                                               NaN  39.920386  32.855093
# 37                         Tunali Hilmi Cad. Çankaya  39.902778  32.860412
# 38                                               NaN  39.919900  32.853558
# 39                                Nenehatun Cad.No.8  39.904282  32.867163
# 40                                               NaN  39.902177  32.860209
# 41                                         İran Cad.  39.896340  32.863069
# 42                          Tunalı Hilmi Cad. No:104  39.903717  32.860297
# 43                                           Çankaya  39.878184  32.847630
# 44                                               NaN  39.919243  32.853280
# 45                                            Ankara  39.935387  32.862514
# 46                                               NaN  39.920519  32.852481
# 47                            Atatürk Bulvarı No:237  39.902623  32.859542
# 48                                               NaN  39.919524  32.852631
# 49                                               NaN  39.905970  32.860754
#
#     distance postalCode  cc neighborhood        city        state  country  \
# 0       2158      06680  TR      Çankaya     Çankaya       Ankara  Türkiye
# 1       2143        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 2       1891        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 3        231        NaN  TR          NaN         NaN          NaN  Türkiye
# 4       2102        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 5       2142        NaN  TR          NaN         NaN          NaN  Türkiye
# 6       2124        NaN  TR          NaN         NaN          NaN  Türkiye
# 7       2148        NaN  TR          NaN         NaN          NaN  Türkiye
# 8       2204        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 9       2102        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 10      2186        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 11      2199        NaN  TR          NaN         NaN          NaN  Türkiye
# 12      2121        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 13      8344        NaN  TR          NaN         NaN          NaN  Türkiye
# 14      6302        NaN  TR          NaN         NaN          NaN  Türkiye
# 15      6197        NaN  TR          NaN         NaN          NaN  Türkiye
# 16      2008        NaN  TR          NaN         NaN          NaN  Türkiye
# 17       144        NaN  TR      Kızılay     Çankaya       Ankara  Türkiye
# 18        61      06420  TR      Kızılay     Çankaya       Ankara  Türkiye
# 19       185      06420  TR          NaN     Çankaya       Ankara  Türkiye
# 20      2076      06680  TR          NaN      Ankara       Ankara  Türkiye
# 21      4110      06510  TR          NaN  Çukurambar       Ankara  Türkiye
# 22       497        NaN  TR          NaN      Ankara          NaN  Türkiye
# 23      2113        NaN  TR          NaN      Ankara  Kavaklıdere  Türkiye
# 24        71      01312  TR          NaN      Ankara       Ankara  Türkiye
# 25      1966      06680  TR          NaN      Ankara       Ankara  Türkiye
# 26      1921        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 27       744        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 28      1715      06200  TR          NaN     Çankaya       Ankara  Türkiye
# 29      2153      06690  TR      Çankaya         NaN       Ankara  Türkiye
# 30      2092      06630  TR          NaN      Ankara       Ankara  Türkiye
# 31      1053        NaN  TR     Kurtuluş     Çankaya       Ankara  Türkiye
# 32      1203      06200  TR  Mebusevleri     Çankaya       Ankara  Türkiye
# 33        94     000606  TR          NaN     Çankaya       Ankara  Türkiye
# 34       978        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 35       359        NaN  TR          NaN         NaN          NaN  Türkiye
# 36       100        NaN  TR          NaN         NaN          NaN  Türkiye
# 37      2077        NaN  TR          NaN      Ankara       Ankara  Türkiye
# 38       107      06420  TR          NaN         NaN       Ankara  Türkiye
# 39      2152        NaN  TR          NaN         NaN          NaN  Türkiye
# 40      2137        NaN  TR          NaN         NaN          NaN  Türkiye
# 41      2828      06690  TR      Çankaya      Ankara       Ankara  Türkiye
# 42      1974      06700  TR          NaN      Ankara       Ankara  Türkiye
# 43      4774      06400  TR          NaN      Ankara       Ankara  Türkiye
# 44       183        NaN  TR          NaN         NaN          NaN  Türkiye
# 45      1778        NaN  TR          NaN         NaN          NaN  Türkiye
# 46       136        NaN  TR          NaN         NaN          NaN  Türkiye
# 47      2076      06660  TR          NaN      Ankara       Ankara  Türkiye
# 48       185        NaN  TR          NaN         NaN          NaN  Türkiye
# 49      1746        NaN  TR          NaN         NaN          NaN  Türkiye
#
#                                      formattedAddress  \
# 0                        [Kavaklıdere, 06680 Çankaya]
# 1   [Atatürk Blv. No:241/A Kuğulupark İçi Kavaklıd...
# 2                     [Atatürk Blv.  Kızılay, Ankara]
# 3                                                 NaN
# 4                               [Kuğulu Park, Ankara]
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                 [Binnaz Sokak, Kavaklıdere, Ankara]
# 9                   [canakaya (tunali hilmi), Ankara]
# 10         [Tunalıhilmi Caddesi, Kavaklıdere, Ankara]
# 11                                                NaN
# 12      [Tunalı Hilmi Caddesi (İran Caddesi), Ankara]
# 13                                 [Park Oran Evleri]
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17            [Kızılay Mah. (Atatürk Bulv.), Çankaya]
# 18  [Kızılay AVM (Kızılay Mah. Gazi Mustafa Kemal ...
# 19  [Kızılay Mah. Milli Müdafaa Cad. No:10/2, 0642...
# 20                [Tunalı Hilmi Cddesi, 06680 Ankara]
# 21     [1443.cadde (1433. Cad. No: 39), 06510 Ankara]
# 22                   [Necatibey Cad. (No:35), Ankara]
# 23        [Tunalı Hilmi Caddesi A blok No:36, Ankara]
# 24    [bilkent mah. (kızılay caddesi.), 01312 Ankara]
# 25                [Büklüm Sk. No:105/B, 06680 Ankara]
# 26                       [Doğanbey Mah. Ulus, Ankara]
# 27           [Şehit Gönenç Cad. No:5 Maltepe, Ankara]
# 28  [Mareşal Fevzi Çakmak Cad. (Mareşal Fevzi Çakm...
# 29                                            [06690]
# 30  [Tunalı Hilmi Caddesi 123/18-51 (Buğday Sokak)...
# 31     [Fidanlık Mah. (Ziya Gökalp Caddesi), Çankaya]
# 32             [Süleymanbey Sk. No:12, 06200 Çankaya]
# 33  [Ankara kızılay metro çarşısı (İzmir caddesi),...
# 34       [Gençlik Caddesi 24 / B (İlk Sokak), Ankara]
# 35                                                NaN
# 36                                                NaN
# 37                [Tunali Hilmi Cad. Çankaya, Ankara]
# 38                                            [06420]
# 39                               [Nenehatun Cad.No.8]
# 40                                                NaN
# 41                          [İran Cad., 06690 Ankara]
# 42           [Tunalı Hilmi Cad. No:104, 06700 Ankara]
# 43                            [Çankaya, 06400 Ankara]
# 44                                                NaN
# 45                                           [Ankara]
# 46                                                NaN
# 47  [Atatürk Bulvarı No:237 (Atatürk Bulvarı), 066...
# 48                                                NaN
# 49                                                NaN
#
#                                        labeledLatLngs  \
# 0                                                 NaN
# 1   [{'label': 'display', 'lat': 39.90207835693736...
# 2   [{'label': 'display', 'lat': 39.90415674576489...
# 3   [{'label': 'display', 'lat': 39.91872, 'lng': ...
# 4   [{'label': 'display', 'lat': 39.902522, 'lng':...
# 5   [{'label': 'display', 'lat': 39.90220635768567...
# 6   [{'label': 'display', 'lat': 39.90237426757812...
# 7   [{'label': 'display', 'lat': 39.90194423797293...
# 8   [{'label': 'display', 'lat': 39.90187796221276...
# 9   [{'label': 'display', 'lat': 39.90255, 'lng': ...
# 10  [{'label': 'display', 'lat': 39.90202159327737...
# 11  [{'label': 'display', 'lat': 39.90219031751395...
# 12  [{'label': 'display', 'lat': 39.90236501367779...
# 13  [{'label': 'display', 'lat': 39.84722049293445...
# 14  [{'label': 'display', 'lat': 39.86428667613971...
# 15  [{'label': 'display', 'lat': 39.86540651380737...
# 16  [{'label': 'display', 'lat': 39.9250373840332,...
# 17  [{'label': 'display', 'lat': 39.91961106614960...
# 18                                                NaN
# 19  [{'label': 'display', 'lat': 39.91991753447189...
# 20  [{'label': 'display', 'lat': 39.90284475918808...
# 21  [{'label': 'display', 'lat': 39.90319131605386...
# 22  [{'label': 'display', 'lat': 39.92392262935146...
# 23  [{'label': 'display', 'lat': 39.90250868310838...
# 24  [{'label': 'display', 'lat': 39.921356, 'lng':...
# 25  [{'label': 'display', 'lat': 39.90516451936961...
# 26                                                NaN
# 27  [{'label': 'display', 'lat': 39.92423521235494...
# 28  [{'label': 'display', 'lat': 39.92186002898943...
# 29  [{'label': 'display', 'lat': 39.90196, 'lng': ...
# 30  [{'label': 'display', 'lat': 39.90265159364201...
# 31  [{'label': 'display', 'lat': 39.926774, 'lng':...
# 32  [{'label': 'display', 'lat': 39.92728836908494...
# 33  [{'label': 'display', 'lat': 39.921638, 'lng':...
# 34  [{'label': 'display', 'lat': 39.92284218088236...
# 35  [{'label': 'display', 'lat': 39.91772782268796...
# 36  [{'label': 'display', 'lat': 39.92038631566025...
# 37  [{'label': 'display', 'lat': 39.90277840314112...
# 38  [{'label': 'display', 'lat': 39.9199, 'lng': 3...
# 39  [{'label': 'display', 'lat': 39.904282, 'lng':...
# 40  [{'label': 'display', 'lat': 39.90217675550652...
# 41  [{'label': 'display', 'lat': 39.89634019041868...
# 42  [{'label': 'display', 'lat': 39.90371685231863...
# 43                                                NaN
# 44  [{'label': 'display', 'lat': 39.919243, 'lng':...
# 45  [{'label': 'display', 'lat': 39.93538665771484...
# 46  [{'label': 'display', 'lat': 39.920519, 'lng':...
# 47  [{'label': 'display', 'lat': 39.902623, 'lng':...
# 48  [{'label': 'display', 'lat': 39.91952398533466...
# 49  [{'label': 'display', 'lat': 39.90596983311837...
#
#                                      crossStreet                        id
# 0                                            NaN  4b8cf019f964a52079e132e3
# 1                                            NaN  4f9298efe4b0c98cdffc4f90
# 2                                            NaN  4d9028ca1d06b1f7f9f06e3b
# 3                                            NaN  5ce24192f4b525002c751db2
# 4                                            NaN  559e888e498e259c0b977a12
# 5                                            NaN  5224fe5f11d21994b56bd69a
# 6                                            NaN  563607ff498e7eaaf5d78b59
# 7                                            NaN  55f44e8a498e93c8cbd6d186
# 8                                            NaN  4f0c3254e4b0065899b06cb1
# 9                                   tunali hilmi  59e377fda35dce662c712223
# 10                                           NaN  4f0ea664e4b06ab9f9605067
# 11                                           NaN  5004227de4b0ebdd73ddb77a
# 12                                  İran Caddesi  58a4162a2ec36409a57171f8
# 13                                           NaN  53a0949d498e50a50db606a6
# 14                                           NaN  4fa04a68e4b0753bece09504
# 15                                           NaN  518519c7498e2061f0317c37
# 16                                           NaN  5658a9fb498e3d9d37af4b2b
# 17                                 Atatürk Bulv.  4c0bf401bbc676b0a2514cd5
# 18  Kızılay Mah. Gazi Mustafa Kemal Bulv. No: 96  4f25511ce4b04f6e6a110d1b
# 19                                           NaN  4ed3aaaa2c5bc3505ac3f95d
# 20                           Tunalı Hilmi Cddesi  4e788e1daeb726a0e669dacd
# 21                             1433. Cad. No: 39  51c1676d498e9abf8368861e
# 22                                         No:35  4dac393a6a2303012f338d77
# 23             Tunalı Hilmi Caddesi A blok No:36  5041cccee4b0aa9bdb998504
# 24                              kızılay caddesi.  5be70808fd9d73002cc7edaf
# 25                                           NaN  4ee6104b0039e47bcd2cb291
# 26                                           NaN  4bb871ef1261d13a669fe898
# 27                                           NaN  4e730c6f45dd41e9ccc10b87
# 28                     Mareşal Fevzi Çakmak Cad.  4cc3eb36306e224b843a9a6c
# 29                                           NaN  57b08dce498ed2d6214ba8f2
# 30                                  Buğday Sokak  4f48bcc1e4b0683d4fd937a2
# 31                           Ziya Gökalp Caddesi  4cf0ea00e9425481530c67c5
# 32                                           NaN  4e47fb62fa76a07fde6de726
# 33                                 İzmir caddesi  57b5e1a238fa0b43a4c29754
# 34                                     İlk Sokak  56dc5ecc498ebb7ab7c1c59c
# 35                                           NaN  5527889d498e8cdeb54d5fc6
# 36                                           NaN  5120a898e4b016d274373cfc
# 37                                           NaN  53c42ce8498e9be7a57aff08
# 38                                           NaN  57c1b28d498e44750d81266c
# 39                                           NaN  5ba614d9fe37400039ee331f
# 40                                           NaN  5131e160e4b021182f976582
# 41                                           NaN  4c684102607ad13a1417a82b
# 42                                           NaN  50c621a8e4b009e3bde8c0d6
# 43                                           NaN  4cdef7beffcf37047c6b1682
# 44                                           NaN  5d4358b2f6ebb000070bcd16
# 45                                           NaN  57b4ab09498ee0286b30df8d
# 46                                           NaN  57ce7fbb498e4c597b09d24a
# 47                               Atatürk Bulvarı  5d98a62895eb490008658e4d
# 48                                           NaN  56bf6169498e0190cd31ddc6
# 49                                           NaN  53edeee3498e415108877112

# %%
dataframe_filtered.name
# Out:
# 0                                           Kuğulu Park
# 1                         Kuğulu Park Restaurant & Cafe
# 2                                Kugulu Park Alt Gecidi
# 3     304 Kırkkonaklar - Gop - Kuğulu Park - Kızılay...
# 4                               kuğulu Park Saat&Çakmak
# 5                          Tarihi Kuğulu Park Köftecisi
# 6                                 Kuğulu Park Simitçisi
# 7      Kuğulu Park Otobüs Durağı -Polonya Büyükelciligi
# 8                                  Kuğulu Park Eczanesi
# 9                                      Kugulu Park Taxi
# 10                                     Kuğulu Park Büfe
# 11                          Kugulu Park Mesrubat Bufesi
# 12                                     A212 Kuğulu Park
# 13                                Park Oran Kuğulu Park
# 14                                        Kugulu Park 2
# 15                                   Yıldız Kuğulu Park
# 16                                     Kuğuluoğlu Parkı
# 17                                            Güvenpark
# 18                                            Starbucks
# 19                                      Güven Park Cafe
# 20                                        Kuğulu Pasajı
# 21                          The Green Park Ankara Hotel
# 22                                  Business Park Hotel
# 23                                    Kuğulu İş Merkezi
# 24                                         Gençlik Park
# 25                             Kuğulu Veteriner Kliniği
# 26                                        Gençlik Parkı
# 27                                         Maltepe Park
# 28                                            Anıt Park
# 29                                       Kuğulu Çankaya
# 30                                         Kuğulu Optik
# 31                                       Kurtuluş Parkı
# 32                                         Ördekli Park
# 33                                  Big Park Giyim B-25
# 34                    Kuğulu Veteriner Kliniği Anıttepe
# 35                                   Life Park Güzellik
# 36                                             Cep Park
# 37                                                 Mado
# 38                                                 Park
# 39                   Kuğulu Veteriner Kliniği Nenehatun
# 40                                   Kuğulu Çocuk Parkı
# 41                     Seğmenler Park (Seğmenler Parkı)
# 42                                Kuğulu Sanat Galerisi
# 43                                     Park Vadi Evleri
# 44                                  Kızıl Ay Güven Park
# 45                                         Kuğulu Plajı
# 46                                            park kafe
# 47                                      A4 Kahve Kuğulu
# 48                                    Kızılay PARK KAFE
# 49                               Kuğulu Vitamin Sandwiç
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f90b0d4674ce4985a39a40c54c058afc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f90b0d4674ce4985a39a40c54c058afc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f90b0d4674ce4985a39a40c54c058afc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f90b0d4674ce4985a39a40c54c058afc%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.9207893%2C%2032.8540412%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
from spylon_kernel import register_ipython_magics
register_ipython_magics()

# %%
# %%scala
# val x = 8
# x
# Out:
# Intitializing Scala interpreter ...
# Spark Web UI available at http://192.168.0.15:4040
# SparkContext available as 'sc' (version = 3.0.1, master = local[*], app id = local-1616701179011)
# SparkSession available as 'spark'

# %%
# %%scala
# val x = 2
# val y = 3
# x*y
