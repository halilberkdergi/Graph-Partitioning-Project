# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas import json_normalize



import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'BAXJ4D2EUQZ1H0PORU3ZNYROWJ4NHTD4ZWXC4JTR0503O3Q1' # your Foursquare ID
CLIENT_SECRET = 'LTTP3N0W0SHVZ4ZFIUWCAE4NGDQX4LEUAGZOMXOOWD5PZPY1' # your Foursquare Secret
ACCESS_TOKEN = 'UCO4AEGWBQA1ZRB5KVFXMLOUDU1IESDXRGI0GCIGKZ1UZQIR' # your FourSquare Access Token
VERSION = '20210227'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BAXJ4D2EUQZ1H0PORU3ZNYROWJ4NHTD4ZWXC4JTR0503O3Q1
# CLIENT_SECRET:LTTP3N0W0SHVZ4ZFIUWCAE4NGDQX4LEUAGZOMXOOWD5PZPY1

# %%
address = 'Ankara'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.9207486 32.8540093

# %%
search_query = 'kafe'
radius=10000
print(search_query + ' .... OK!')
# Out:
# kafe .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=BAXJ4D2EUQZ1H0PORU3ZNYROWJ4NHTD4ZWXC4JTR0503O3Q1&client_secret=LTTP3N0W0SHVZ4ZFIUWCAE4NGDQX4LEUAGZOMXOOWD5PZPY1&ll=39.9207486,32.8540093&oauth_token=UCO4AEGWBQA1ZRB5KVFXMLOUDU1IESDXRGI0GCIGKZ1UZQIR&v=20210227&query=kafe&radius=10000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '604d2143511b4e7cb65b0273'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '5498847e498e8683bf335cba',
#     'name': 'Karikatür Bi Kafe',
#     'location': {'address': 'Karanfil Sok. No:49/7 Kızılay',
#      'lat': 39.91636580895385,
#      'lng': 32.855662551759806,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91636580895385,
#        'lng': 32.855662551759806}],
#      'distance': 507,
#      'cc': 'TR',
#      'neighborhood': 'Çankaya',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Karanfil Sok. No:49/7 Kızılay', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '4fec4b22e4b0044db3f03d9a',
#     'name': 'Kızılay Fal Merkezi & Kafe',
#     'location': {'address': 'Yüksel Cad. No:8/19.20.21',
#      'lat': 39.91933720367413,
#      'lng': 32.85570296486829,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91933720367413,
#        'lng': 32.85570296486829}],
#      'distance': 213,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Yüksel Cad. No:8/19.20.21', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '54395353498e6f51e69dae43',
#     'name': 'Nazım Hikmet Kültür Merkezi Şair Kafe Sahnesi',
#     'location': {'address': 'Konur Sok. No:51 Kızılay',
#      'lat': 39.915912957557275,
#      'lng': 32.85766127541424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.915912957557275,
#        'lng': 32.85766127541424}],
#      'distance': 622,
#      'postalCode': '06540',
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Konur Sok. No:51 Kızılay', '06540 Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '50ce209de4b044fa5bdb1681',
#     'name': 'Çınar Kafe',
#     'location': {'lat': 39.91514480873323,
#      'lng': 32.85587447642523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91514480873323,
#        'lng': 32.85587447642523}],
#      'distance': 643,
#      'cc': 'TR',
#      'neighborhood': 'Çankaya',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5ace189a6adbf52451461053',
#     'name': 'Turuncu Kafe',
#     'location': {'address': 'kızılay',
#      'crossStreet': 'ulus cad',
#      'lat': 39.92423,
#      'lng': 32.85264,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92423,
#        'lng': 32.85264}],
#      'distance': 404,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['kızılay (ulus cad)', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '4d9f08278ef3a143bf428910',
#     'name': 'Ayça İnternet Kafe',
#     'location': {'address': 'Sakarya Caddesı Yanı.',
#      'lat': 39.92194201618541,
#      'lng': 32.85714872284717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92194201618541,
#        'lng': 32.85714872284717}],
#      'distance': 299,
#      'cc': 'TR',
#      'city': 'Kızılay',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Sakarya Caddesı Yanı.', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1f0941735',
#       'name': 'Internet Cafe',
#       'pluralName': 'Internet Cafes',
#       'shortName': 'Internet Cafe',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/internetcafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '4e3989ca18a8d2fcc62ce92a',
#     'name': 'Anıttepe Kafe Market',
#     'location': {'address': 'Kocatepe Mah.',
#      'lat': 39.918405564387896,
#      'lng': 32.85740764190024,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.918405564387896,
#        'lng': 32.85740764190024}],
#      'distance': 390,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Kocatepe Mah.', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '53cd2e30498e6baf0b1b4f4a',
#     'name': 'Kafe Karanfil',
#     'location': {'address': 'KIZILAY Karanfil 1 Sok. 5 (KARANFİL METRO ÇIKIŞI)',
#      'lat': 39.92037042063917,
#      'lng': 32.85557431133451,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92037042063917,
#        'lng': 32.85557431133451}],
#      'distance': 140,
#      'postalCode': '06420',
#      'cc': 'TR',
#      'city': 'Çankaya',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['KIZILAY Karanfil 1 Sok. 5 (KARANFİL METRO ÇIKIŞI)',
#       '06420 ANKARA']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '106894954'},
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5144ba66e4b0853bebbba20b',
#     'name': 'Tiyatro Kafe',
#     'location': {'address': 'Tunalı Hilmi Cad. 111/8 Kavaklıdere/Ankara',
#      'crossStreet': 'Tunalı Hilmi',
#      'lat': 39.90455755068576,
#      'lng': 32.86064386367798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.90455755068576,
#        'lng': 32.86064386367798}],
#      'distance': 1889,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Tunalı Hilmi Cad. 111/8 Kavaklıdere/Ankara (Tunalı Hilmi)',
#       'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '422913940'},
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5c559f1da9e402002ce043f8',
#     'name': 'Pucca Kafe',
#     'location': {'lat': 39.921165,
#      'lng': 32.85444,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.921165,
#        'lng': 32.85444}],
#      'distance': 59,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '56bf6169498e0190cd31ddc6',
#     'name': 'Kızılay PARK KAFE',
#     'location': {'lat': 39.91952398533466,
#      'lng': 32.85263095923436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91952398533466,
#        'lng': 32.85263095923436}],
#      'distance': 180,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '56f408a7498e3933d7c255b9',
#     'name': 'Mekan Kafe',
#     'location': {'address': 'Atatürk Bulvarı',
#      'crossStreet': 'Atatürk Bulvarı',
#      'lat': 39.92216572049144,
#      'lng': 32.85406245946557,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92216572049144,
#        'lng': 32.85406245946557}],
#      'distance': 157,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Atatürk Bulvarı (Atatürk Bulvarı)', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '4c7556dbb474a1cdacf9b8bf',
#     'name': 'Ezgi Cafe',
#     'location': {'address': 'Konur Sk. No:14/A Kızılay',
#      'lat': 39.91837283124024,
#      'lng': 32.85576717739065,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91837283124024,
#        'lng': 32.85576717739065}],
#      'distance': 304,
#      'postalCode': '06420',
#      'cc': 'TR',
#      'neighborhood': 'Çankaya',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Konur Sk. No:14/A Kızılay', '06420 Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '4fa97010e4b04afbc0e3c84d',
#     'name': 'Park Kafe',
#     'location': {'address': 'Gençlik Parki Içi',
#      'lat': 39.93651945301305,
#      'lng': 32.8497300117522,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.93651945301305,
#        'lng': 32.8497300117522}],
#      'distance': 1793,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Gençlik Parki Içi', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '57ce7fbb498e4c597b09d24a',
#     'name': 'park kafe',
#     'location': {'lat': 39.920519,
#      'lng': 32.852481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.920519,
#        'lng': 32.852481}],
#      'distance': 132,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5e4e311578303e000871acb4',
#     'name': 'Limit Kütüphane-Kafe-Kurs',
#     'location': {'address': 'Sakarya Caddesi No:18',
#      'crossStreet': 'Sakarya Caddesi',
#      'lat': 39.922104,
#      'lng': 32.856285,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.922104,
#        'lng': 32.856285}],
#      'distance': 245,
#      'postalCode': '06420',
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Sakarya Caddesi No:18 (Sakarya Caddesi)',
#       '06420 Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '521b772611d29cbfea4567b0',
#     'name': 'Kızılay Tarot Kafe',
#     'location': {'lat': 39.92184073222648,
#      'lng': 32.854850398554625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92184073222648,
#        'lng': 32.854850398554625}],
#      'distance': 141,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5152cbaae4b0659b3119609b',
#     'name': 'Gülçin Kafe',
#     'location': {'lat': 39.92134072592684,
#      'lng': 32.85534054110231,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92134072592684,
#        'lng': 32.85534054110231}],
#      'distance': 131,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5040c327e4b06be18f8c08f5',
#     'name': 'Kafe Kanape',
#     'location': {'address': 'İzmir Cad. No:34 D:17 Kızılay Çankaya',
#      'lat': 39.921454,
#      'lng': 32.85147,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.921454,
#        'lng': 32.85147}],
#      'distance': 230,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['İzmir Cad. No:34 D:17 Kızılay Çankaya', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '4fc8d366e4b04ec64b1cbdcd',
#     'name': 'Tabut Kafe',
#     'location': {'address': 'Meşrutiyet Cad. Konur 2 Sok. No:27/3 Çankaya',
#      'lat': 39.919440280818826,
#      'lng': 32.85461909450272,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.919440280818826,
#        'lng': 32.85461909450272}],
#      'distance': 154,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Meşrutiyet Cad. Konur 2 Sok. No:27/3 Çankaya',
#       'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '53581634498eca0421fc4625',
#     'name': 'ortaköy kafe bar',
#     'location': {'address': 'Kızılay',
#      'crossStreet': 'Atatürk Bulvarı',
#      'lat': 39.922242749845815,
#      'lng': 32.85384807716597,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.922242749845815,
#        'lng': 32.85384807716597}],
#      'distance': 166,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Kızılay (Atatürk Bulvarı)', 'Ankara']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '56d6d90d498ef2bd01c0aefc',
#     'name': 'altın kafe',
#     'location': {'address': 'Ziya Gökalp Cad No:9/35',
#      'lat': 39.9211240141896,
#      'lng': 32.855852709983886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.9211240141896,
#        'lng': 32.855852709983886}],
#      'distance': 162,
#      'cc': 'TR',
#      'city': 'Kızılay',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ziya Gökalp Cad No:9/35', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '577d1551498e4a16c8a927d0',
#     'name': 'Karaca Kafe',
#     'location': {'address': 'Ankara Kizilay',
#      'lat': 39.918896,
#      'lng': 32.853527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.918896,
#        'lng': 32.853527}],
#      'distance': 210,
#      'cc': 'TR',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara Kizilay']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '512f2eece4b0c636267e75ef',
#     'name': 'Kafe Karamel kahve falinda bir numara LEYLA',
#     'location': {'address': 'Karanfil Sokak',
#      'crossStreet': '25/4',
#      'lat': 39.918413270059936,
#      'lng': 32.855164310348144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.918413270059936,
#        'lng': 32.855164310348144}],
#      'distance': 278,
#      'cc': 'TR',
#      'country': 'Türkiye',
#      'formattedAddress': ['Karanfil Sokak (25/4)']},
#     'categories': [{'id': '4bf58dd8d48988d116951735',
#       'name': 'Antique Shop',
#       'pluralName': 'Antique Shops',
#       'shortName': 'Antiques',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '51629160e4b00ea019853286',
#     'name': 'Kültür Kafe',
#     'location': {'lat': 39.938359,
#      'lng': 32.849017,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.938359,
#        'lng': 32.849017}],
#      'distance': 2006,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '51d4628e498e7eba71e572e7',
#     'name': 'Asyam Kafe',
#     'location': {'lat': 39.92013751537102,
#      'lng': 32.85587473869466,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92013751537102,
#        'lng': 32.85587473869466}],
#      'distance': 173,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '514f4f64e4b03149222f44d7',
#     'name': 'Döpi Kafe',
#     'location': {'lat': 39.91941061689743,
#      'lng': 32.855993179616085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91941061689743,
#        'lng': 32.855993179616085}],
#      'distance': 225,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5980b9e81fa7630c41df5c71',
#     'name': 'Simit Kafe',
#     'location': {'lat': 39.92197,
#      'lng': 32.85594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92197,
#        'lng': 32.85594}],
#      'distance': 213,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d179941735',
#       'name': 'Bagel Shop',
#       'pluralName': 'Bagel Shops',
#       'shortName': 'Bagels',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '51e17fae8bbd74f34b602ede',
#     'name': 'Kardelen İnternet Kafe',
#     'location': {'address': 'Tellikaya Sokak No:3/A Çankaya',
#      'crossStreet': 'Cemal Gürsel',
#      'lat': 39.93004392443944,
#      'lng': 32.878298163414,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.93004392443944,
#        'lng': 32.878298163414}],
#      'distance': 2317,
#      'postalCode': '06480',
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Tellikaya Sokak No:3/A Çankaya (Cemal Gürsel)',
#       '06480 Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1f0941735',
#       'name': 'Internet Cafe',
#       'pluralName': 'Internet Cafes',
#       'shortName': 'Internet Cafe',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/internetcafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '528b6973498e5c7b36358756',
#     'name': 'Sevgi Kafe',
#     'location': {'address': 'Kizilay',
#      'lat': 39.922451656272884,
#      'lng': 32.85400228110475,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.922451656272884,
#        'lng': 32.85400228110475}],
#      'distance': 189,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Kizilay', 'Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '53f4c986498e94d155ce525f',
#     'name': 'Mülkiye Gençlik Kafe',
#     'location': {'lat': 39.91926159571338,
#      'lng': 32.85675037605105,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91926159571338,
#        'lng': 32.85675037605105}],
#      'distance': 286,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '51c1aceb498e2bd1db31a162',
#     'name': "Kafe 'D' Keyf",
#     'location': {'address': 'Prof. M. Aksoy Cad. Bahçelievler',
#      'lat': 39.93126672955539,
#      'lng': 32.82639887097901,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.93126672955539,
#        'lng': 32.82639887097901}],
#      'distance': 2631,
#      'cc': 'TR',
#      'city': 'Bahçelievler',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Prof. M. Aksoy Cad. Bahçelievler', 'Bahçelievler']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '514f055be4b031491f3fbfcd',
#     'name': 'Özgür Kafe',
#     'location': {'lat': 39.923308247543,
#      'lng': 32.8565326882608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.923308247543,
#        'lng': 32.8565326882608}],
#      'distance': 357,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '4e3af6d97d8b90abc32d5691',
#     'name': 'Art Kafe & Çay Evi',
#     'location': {'lat': 39.920384427429994,
#      'lng': 32.85701411650985,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.920384427429994,
#        'lng': 32.85701411650985}],
#      'distance': 259,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '53b15e0b498e5522d455b5a2',
#     'name': 'İn Kafe',
#     'location': {'lat': 39.92222695676365,
#      'lng': 32.85716891700779,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92222695676365,
#        'lng': 32.85716891700779}],
#      'distance': 315,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '57c2db02498e960e0b79ee0d',
#     'name': 'Uzman Kafe',
#     'location': {'address': 'karanfil sokak',
#      'crossStreet': 'Meşrutiyet caddesi',
#      'lat': 39.918488,
#      'lng': 32.8552,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.918488,
#        'lng': 32.8552}],
#      'distance': 271,
#      'postalCode': '06420',
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['karanfil sokak (Meşrutiyet caddesi)',
#       '06420 Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '53d8f190498ef67568454c97',
#     'name': 'T-Kafe',
#     'location': {'lat': 39.923293520218465,
#      'lng': 32.852768642994846,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.923293520218465,
#        'lng': 32.852768642994846}],
#      'distance': 302,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '56c183c5cd10bb645fa79d75',
#     'name': 'Çevik Kafe',
#     'location': {'lat': 39.91842254262454,
#      'lng': 32.85342952242971,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91842254262454,
#        'lng': 32.85342952242971}],
#      'distance': 263,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5310980611d2961d7baf3f0d',
#     'name': 'Mekan Kitap Kafe',
#     'location': {'address': 'Kızılay',
#      'lat': 39.919979444643,
#      'lng': 32.857339637162454,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.919979444643,
#        'lng': 32.857339637162454}],
#      'distance': 296,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Kızılay', 'Ankara']},
#     'categories': [],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '56dc84a0cd108a3947a6f810',
#     'name': 'Sem Kafe',
#     'location': {'lat': 39.919292699751466,
#      'lng': 32.856921096914206,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.919292699751466,
#        'lng': 32.856921096914206}],
#      'distance': 296,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '51124de1e4b05bd664cf43e9',
#     'name': 'Alaturka kafe',
#     'location': {'lat': 39.919402896280026,
#      'lng': 32.851270633582544,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.919402896280026,
#        'lng': 32.851270633582544}],
#      'distance': 277,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5a59e5c6c66666463e20ffb1',
#     'name': '+1 Kafe',
#     'location': {'lat': 39.920082,
#      'lng': 32.857243,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.920082,
#        'lng': 32.857243}],
#      'distance': 285,
#      'postalCode': '06420',
#      'cc': 'TR',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['06420']},
#     'categories': [{'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '53482964498e9b8b62ba4c18',
#     'name': 'Türkü kafe pub',
#     'location': {'lat': 39.922786712646484,
#      'lng': 32.855995178222656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.922786712646484,
#        'lng': 32.855995178222656}],
#      'distance': 283,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '543bfcf3498e0a3393ce325d',
#     'name': 'ladus kafe',
#     'location': {'lat': 39.91870127694184,
#      'lng': 32.85616661865812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91870127694184,
#        'lng': 32.85616661865812}],
#      'distance': 293,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '53c430a5498e3b5ccb0d9b02',
#     'name': 'Çaldıran Kafe-Oyun Salonu',
#     'location': {'lat': 39.92283471295193,
#      'lng': 32.85621618309632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92283471295193,
#        'lng': 32.85621618309632}],
#      'distance': 299,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1e1931735',
#       'name': 'Arcade',
#       'pluralName': 'Arcades',
#       'shortName': 'Arcade',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/arcade_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5636eb82498ef83084af5773',
#     'name': 'Fırıncım teras kafe',
#     'location': {'lat': 39.923035627893945,
#      'lng': 32.85359680678616,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.923035627893945,
#        'lng': 32.85359680678616}],
#      'distance': 257,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '52e81612bcbc57f1066b79f1',
#       'name': 'Bistro',
#       'pluralName': 'Bistros',
#       'shortName': 'Bistro',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '5220c9ed11d287f1222b9229',
#     'name': 'kapi7 kafe restaurant',
#     'location': {'lat': 39.91719557057093,
#      'lng': 32.85656864062111,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91719557057093,
#        'lng': 32.85656864062111}],
#      'distance': 451,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '576fe805498e2794c1a58b40',
#     'name': 'Ada Kafe',
#     'location': {'lat': 39.92304,
#      'lng': 32.856712,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.92304,
#        'lng': 32.856712}],
#      'distance': 343,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '4bf58dd8d48988d1e1931735',
#       'name': 'Arcade',
#       'pluralName': 'Arcades',
#       'shortName': 'Arcade',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/arcade_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '53c2bbcd498e8361723ec01f',
#     'name': 'Gazi Kafe',
#     'location': {'lat': 39.91117527581051,
#      'lng': 32.82570149345491,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.91117527581051,
#        'lng': 32.82570149345491}],
#      'distance': 2641,
#      'cc': 'TR',
#      'city': 'Ankara',
#      'state': 'Ankara',
#      'country': 'Türkiye',
#      'formattedAddress': ['Ankara']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False},
#    {'id': '55dddc4c498ef83596813937',
#     'name': 'Ezgi Kafe',
#     'location': {'lat': 39.9179717080729,
#      'lng': 32.85526160442801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.9179717080729,
#        'lng': 32.85526160442801}],
#      'distance': 327,
#      'cc': 'TR',
#      'country': 'Türkiye'},
#     'categories': [{'id': '5267e4d9e4b0ec79466e48c9',
#       'name': 'Convention',
#       'pluralName': 'Conventions',
#       'shortName': 'Convention',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/event/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615667523',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                           name  \
# 0  5498847e498e8683bf335cba                              Karikatür Bi Kafe
# 1  4fec4b22e4b0044db3f03d9a                     Kızılay Fal Merkezi & Kafe
# 2  54395353498e6f51e69dae43  Nazım Hikmet Kültür Merkezi Şair Kafe Sahnesi
# 3  50ce209de4b044fa5bdb1681                                     Çınar Kafe
# 4  5ace189a6adbf52451461053                                   Turuncu Kafe
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615667523    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615667523    False
# 2  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...  v-1615667523    False
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615667523    False
# 4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615667523    False
#
#                 location.address  location.lat  location.lng  \
# 0  Karanfil Sok. No:49/7 Kızılay     39.916366     32.855663
# 1      Yüksel Cad. No:8/19.20.21     39.919337     32.855703
# 2       Konur Sok. No:51 Kızılay     39.915913     32.857661
# 3                            NaN     39.915145     32.855874
# 4                        kızılay     39.924230     32.852640
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 39.91636580895385...                507
# 1  [{'label': 'display', 'lat': 39.91933720367413...                213
# 2  [{'label': 'display', 'lat': 39.91591295755727...                622
# 3  [{'label': 'display', 'lat': 39.91514480873323...                643
# 4  [{'label': 'display', 'lat': 39.92423, 'lng': ...                404
#
#   location.cc location.neighborhood location.city location.state  \
# 0          TR               Çankaya        Ankara         Ankara
# 1          TR                   NaN        Ankara         Ankara
# 2          TR                   NaN        Ankara         Ankara
# 3          TR               Çankaya        Ankara         Ankara
# 4          TR                   NaN        Ankara         Ankara
#
#   location.country                 location.formattedAddress  \
# 0          Türkiye   [Karanfil Sok. No:49/7 Kızılay, Ankara]
# 1          Türkiye       [Yüksel Cad. No:8/19.20.21, Ankara]
# 2          Türkiye  [Konur Sok. No:51 Kızılay, 06540 Ankara]
# 3          Türkiye                                  [Ankara]
# 4          Türkiye              [kızılay (ulus cad), Ankara]
#
#   location.postalCode location.crossStreet venuePage.id
# 0                 NaN                  NaN          NaN
# 1                 NaN                  NaN          NaN
# 2               06540                  NaN          NaN
# 3                 NaN                  NaN          NaN
# 4                 NaN             ulus cad          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                              name             categories  \
# 0                               Karikatür Bi Kafe                   Café
# 1                      Kızılay Fal Merkezi & Kafe                   Café
# 2   Nazım Hikmet Kültür Merkezi Şair Kafe Sahnesi            Art Gallery
# 3                                      Çınar Kafe                   Café
# 4                                    Turuncu Kafe                   Café
# 5                              Ayça İnternet Kafe          Internet Cafe
# 6                            Anıttepe Kafe Market                   Café
# 7                                   Kafe Karanfil                   Café
# 8                                    Tiyatro Kafe                   Café
# 9                                      Pucca Kafe                   Café
# 10                              Kızılay PARK KAFE                   Café
# 11                                     Mekan Kafe                   Café
# 12                                      Ezgi Cafe                   Café
# 13                                      Park Kafe                   Café
# 14                                      park kafe                   Café
# 15                      Limit Kütüphane-Kafe-Kurs                Library
# 16                             Kızılay Tarot Kafe  General Entertainment
# 17                                    Gülçin Kafe                   Café
# 18                                    Kafe Kanape                   Café
# 19                                     Tabut Kafe                   Café
# 20                               ortaköy kafe bar                Brewery
# 21                                     altın kafe                  Diner
# 22                                    Karaca Kafe              Nightclub
# 23    Kafe Karamel kahve falinda bir numara LEYLA           Antique Shop
# 24                                    Kültür Kafe                   Café
# 25                                     Asyam Kafe  General Entertainment
# 26                                      Döpi Kafe    American Restaurant
# 27                                     Simit Kafe             Bagel Shop
# 28                         Kardelen İnternet Kafe          Internet Cafe
# 29                                     Sevgi Kafe                   Café
# 30                           Mülkiye Gençlik Kafe                 Garden
# 31                                  Kafe 'D' Keyf                   Café
# 32                                     Özgür Kafe                    Bar
# 33                             Art Kafe & Çay Evi                   Café
# 34                                        İn Kafe                   Café
# 35                                     Uzman Kafe      College Cafeteria
# 36                                         T-Kafe                   Café
# 37                                     Çevik Kafe                   Café
# 38                               Mekan Kitap Kafe                   None
# 39                                       Sem Kafe              Cafeteria
# 40                                  Alaturka kafe     Turkish Restaurant
# 41                                        +1 Kafe      College Cafeteria
# 42                                 Türkü kafe pub                    Bar
# 43                                     ladus kafe                   Café
# 44                      Çaldıran Kafe-Oyun Salonu                 Arcade
# 45                            Fırıncım teras kafe                 Bistro
# 46                          kapi7 kafe restaurant           Cocktail Bar
# 47                                       Ada Kafe                 Arcade
# 48                                      Gazi Kafe                  Diner
# 49                                      Ezgi Kafe             Convention
#
#                                               address        lat        lng  \
# 0                       Karanfil Sok. No:49/7 Kızılay  39.916366  32.855663
# 1                           Yüksel Cad. No:8/19.20.21  39.919337  32.855703
# 2                            Konur Sok. No:51 Kızılay  39.915913  32.857661
# 3                                                 NaN  39.915145  32.855874
# 4                                             kızılay  39.924230  32.852640
# 5                               Sakarya Caddesı Yanı.  39.921942  32.857149
# 6                                       Kocatepe Mah.  39.918406  32.857408
# 7   KIZILAY Karanfil 1 Sok. 5 (KARANFİL METRO ÇIKIŞI)  39.920370  32.855574
# 8          Tunalı Hilmi Cad. 111/8 Kavaklıdere/Ankara  39.904558  32.860644
# 9                                                 NaN  39.921165  32.854440
# 10                                                NaN  39.919524  32.852631
# 11                                    Atatürk Bulvarı  39.922166  32.854062
# 12                          Konur Sk. No:14/A Kızılay  39.918373  32.855767
# 13                                  Gençlik Parki Içi  39.936519  32.849730
# 14                                                NaN  39.920519  32.852481
# 15                              Sakarya Caddesi No:18  39.922104  32.856285
# 16                                                NaN  39.921841  32.854850
# 17                                                NaN  39.921341  32.855341
# 18              İzmir Cad. No:34 D:17 Kızılay Çankaya  39.921454  32.851470
# 19       Meşrutiyet Cad. Konur 2 Sok. No:27/3 Çankaya  39.919440  32.854619
# 20                                            Kızılay  39.922243  32.853848
# 21                            Ziya Gökalp Cad No:9/35  39.921124  32.855853
# 22                                     Ankara Kizilay  39.918896  32.853527
# 23                                     Karanfil Sokak  39.918413  32.855164
# 24                                                NaN  39.938359  32.849017
# 25                                                NaN  39.920138  32.855875
# 26                                                NaN  39.919411  32.855993
# 27                                                NaN  39.921970  32.855940
# 28                     Tellikaya Sokak No:3/A Çankaya  39.930044  32.878298
# 29                                            Kizilay  39.922452  32.854002
# 30                                                NaN  39.919262  32.856750
# 31                   Prof. M. Aksoy Cad. Bahçelievler  39.931267  32.826399
# 32                                                NaN  39.923308  32.856533
# 33                                                NaN  39.920384  32.857014
# 34                                                NaN  39.922227  32.857169
# 35                                     karanfil sokak  39.918488  32.855200
# 36                                                NaN  39.923294  32.852769
# 37                                                NaN  39.918423  32.853430
# 38                                            Kızılay  39.919979  32.857340
# 39                                                NaN  39.919293  32.856921
# 40                                                NaN  39.919403  32.851271
# 41                                                NaN  39.920082  32.857243
# 42                                                NaN  39.922787  32.855995
# 43                                                NaN  39.918701  32.856167
# 44                                                NaN  39.922835  32.856216
# 45                                                NaN  39.923036  32.853597
# 46                                                NaN  39.917196  32.856569
# 47                                                NaN  39.923040  32.856712
# 48                                                NaN  39.911175  32.825701
# 49                                                NaN  39.917972  32.855262
#
#                                        labeledLatLngs  distance  cc  \
# 0   [{'label': 'display', 'lat': 39.91636580895385...       507  TR
# 1   [{'label': 'display', 'lat': 39.91933720367413...       213  TR
# 2   [{'label': 'display', 'lat': 39.91591295755727...       622  TR
# 3   [{'label': 'display', 'lat': 39.91514480873323...       643  TR
# 4   [{'label': 'display', 'lat': 39.92423, 'lng': ...       404  TR
# 5   [{'label': 'display', 'lat': 39.92194201618541...       299  TR
# 6   [{'label': 'display', 'lat': 39.91840556438789...       390  TR
# 7   [{'label': 'display', 'lat': 39.92037042063917...       140  TR
# 8   [{'label': 'display', 'lat': 39.90455755068576...      1889  TR
# 9   [{'label': 'display', 'lat': 39.921165, 'lng':...        59  TR
# 10  [{'label': 'display', 'lat': 39.91952398533466...       180  TR
# 11  [{'label': 'display', 'lat': 39.92216572049144...       157  TR
# 12  [{'label': 'display', 'lat': 39.91837283124024...       304  TR
# 13  [{'label': 'display', 'lat': 39.93651945301305...      1793  TR
# 14  [{'label': 'display', 'lat': 39.920519, 'lng':...       132  TR
# 15  [{'label': 'display', 'lat': 39.922104, 'lng':...       245  TR
# 16  [{'label': 'display', 'lat': 39.92184073222648...       141  TR
# 17  [{'label': 'display', 'lat': 39.92134072592684...       131  TR
# 18  [{'label': 'display', 'lat': 39.921454, 'lng':...       230  TR
# 19  [{'label': 'display', 'lat': 39.91944028081882...       154  TR
# 20  [{'label': 'display', 'lat': 39.92224274984581...       166  TR
# 21  [{'label': 'display', 'lat': 39.9211240141896,...       162  TR
# 22  [{'label': 'display', 'lat': 39.918896, 'lng':...       210  TR
# 23  [{'label': 'display', 'lat': 39.91841327005993...       278  TR
# 24  [{'label': 'display', 'lat': 39.938359, 'lng':...      2006  TR
# 25  [{'label': 'display', 'lat': 39.92013751537102...       173  TR
# 26  [{'label': 'display', 'lat': 39.91941061689743...       225  TR
# 27  [{'label': 'display', 'lat': 39.92197, 'lng': ...       213  TR
# 28  [{'label': 'display', 'lat': 39.93004392443944...      2317  TR
# 29  [{'label': 'display', 'lat': 39.92245165627288...       189  TR
# 30  [{'label': 'display', 'lat': 39.91926159571338...       286  TR
# 31  [{'label': 'display', 'lat': 39.93126672955539...      2631  TR
# 32  [{'label': 'display', 'lat': 39.923308247543, ...       357  TR
# 33  [{'label': 'display', 'lat': 39.92038442742999...       259  TR
# 34  [{'label': 'display', 'lat': 39.92222695676365...       315  TR
# 35  [{'label': 'display', 'lat': 39.918488, 'lng':...       271  TR
# 36  [{'label': 'display', 'lat': 39.92329352021846...       302  TR
# 37  [{'label': 'display', 'lat': 39.91842254262454...       263  TR
# 38  [{'label': 'display', 'lat': 39.919979444643, ...       296  TR
# 39  [{'label': 'display', 'lat': 39.91929269975146...       296  TR
# 40  [{'label': 'display', 'lat': 39.91940289628002...       277  TR
# 41  [{'label': 'display', 'lat': 39.920082, 'lng':...       285  TR
# 42  [{'label': 'display', 'lat': 39.92278671264648...       283  TR
# 43  [{'label': 'display', 'lat': 39.91870127694184...       293  TR
# 44  [{'label': 'display', 'lat': 39.92283471295193...       299  TR
# 45  [{'label': 'display', 'lat': 39.92303562789394...       257  TR
# 46  [{'label': 'display', 'lat': 39.91719557057093...       451  TR
# 47  [{'label': 'display', 'lat': 39.92304, 'lng': ...       343  TR
# 48  [{'label': 'display', 'lat': 39.91117527581051...      2641  TR
# 49  [{'label': 'display', 'lat': 39.9179717080729,...       327  TR
#
#    neighborhood          city   state  country  \
# 0       Çankaya        Ankara  Ankara  Türkiye
# 1           NaN        Ankara  Ankara  Türkiye
# 2           NaN        Ankara  Ankara  Türkiye
# 3       Çankaya        Ankara  Ankara  Türkiye
# 4           NaN        Ankara  Ankara  Türkiye
# 5           NaN       Kızılay  Ankara  Türkiye
# 6           NaN        Ankara  Ankara  Türkiye
# 7           NaN       Çankaya  Ankara  Türkiye
# 8           NaN        Ankara  Ankara  Türkiye
# 9           NaN           NaN     NaN  Türkiye
# 10          NaN           NaN     NaN  Türkiye
# 11          NaN        Ankara  Ankara  Türkiye
# 12      Çankaya        Ankara  Ankara  Türkiye
# 13          NaN        Ankara  Ankara  Türkiye
# 14          NaN           NaN     NaN  Türkiye
# 15          NaN        Ankara  Ankara  Türkiye
# 16          NaN           NaN     NaN  Türkiye
# 17          NaN           NaN     NaN  Türkiye
# 18          NaN        Ankara  Ankara  Türkiye
# 19          NaN        Ankara  Ankara  Türkiye
# 20          NaN        Ankara  Ankara  Türkiye
# 21          NaN       Kızılay  Ankara  Türkiye
# 22          NaN           NaN     NaN  Türkiye
# 23          NaN           NaN     NaN  Türkiye
# 24          NaN           NaN     NaN  Türkiye
# 25          NaN           NaN     NaN  Türkiye
# 26          NaN           NaN     NaN  Türkiye
# 27          NaN           NaN     NaN  Türkiye
# 28          NaN        Ankara  Ankara  Türkiye
# 29          NaN        Ankara  Ankara  Türkiye
# 30          NaN           NaN     NaN  Türkiye
# 31          NaN  Bahçelievler  Ankara  Türkiye
# 32          NaN        Ankara  Ankara  Türkiye
# 33          NaN        Ankara  Ankara  Türkiye
# 34          NaN           NaN     NaN  Türkiye
# 35          NaN        Ankara  Ankara  Türkiye
# 36          NaN           NaN     NaN  Türkiye
# 37          NaN           NaN     NaN  Türkiye
# 38          NaN        Ankara  Ankara  Türkiye
# 39          NaN           NaN     NaN  Türkiye
# 40          NaN           NaN     NaN  Türkiye
# 41          NaN           NaN  Ankara  Türkiye
# 42          NaN           NaN     NaN  Türkiye
# 43          NaN           NaN     NaN  Türkiye
# 44          NaN           NaN     NaN  Türkiye
# 45          NaN           NaN     NaN  Türkiye
# 46          NaN           NaN     NaN  Türkiye
# 47          NaN           NaN     NaN  Türkiye
# 48          NaN        Ankara  Ankara  Türkiye
# 49          NaN           NaN     NaN  Türkiye
#
#                                      formattedAddress postalCode  \
# 0             [Karanfil Sok. No:49/7 Kızılay, Ankara]        NaN
# 1                 [Yüksel Cad. No:8/19.20.21, Ankara]        NaN
# 2            [Konur Sok. No:51 Kızılay, 06540 Ankara]      06540
# 3                                            [Ankara]        NaN
# 4                        [kızılay (ulus cad), Ankara]        NaN
# 5                     [Sakarya Caddesı Yanı., Ankara]        NaN
# 6                             [Kocatepe Mah., Ankara]        NaN
# 7   [KIZILAY Karanfil 1 Sok. 5 (KARANFİL METRO ÇIK...      06420
# 8   [Tunalı Hilmi Cad. 111/8 Kavaklıdere/Ankara (T...        NaN
# 9                                                 NaN        NaN
# 10                                                NaN        NaN
# 11        [Atatürk Bulvarı (Atatürk Bulvarı), Ankara]        NaN
# 12          [Konur Sk. No:14/A Kızılay, 06420 Ankara]      06420
# 13                        [Gençlik Parki Içi, Ankara]        NaN
# 14                                                NaN        NaN
# 15  [Sakarya Caddesi No:18 (Sakarya Caddesi), 0642...      06420
# 16                                                NaN        NaN
# 17                                                NaN        NaN
# 18    [İzmir Cad. No:34 D:17 Kızılay Çankaya, Ankara]        NaN
# 19  [Meşrutiyet Cad. Konur 2 Sok. No:27/3 Çankaya,...        NaN
# 20                [Kızılay (Atatürk Bulvarı), Ankara]        NaN
# 21                  [Ziya Gökalp Cad No:9/35, Ankara]        NaN
# 22                                   [Ankara Kizilay]        NaN
# 23                            [Karanfil Sokak (25/4)]        NaN
# 24                                                NaN        NaN
# 25                                                NaN        NaN
# 26                                                NaN        NaN
# 27                                                NaN        NaN
# 28  [Tellikaya Sokak No:3/A Çankaya (Cemal Gürsel)...      06480
# 29                                  [Kizilay, Ankara]        NaN
# 30                                                NaN        NaN
# 31   [Prof. M. Aksoy Cad. Bahçelievler, Bahçelievler]        NaN
# 32                                           [Ankara]        NaN
# 33                                           [Ankara]        NaN
# 34                                                NaN        NaN
# 35  [karanfil sokak (Meşrutiyet caddesi), 06420 An...      06420
# 36                                                NaN        NaN
# 37                                                NaN        NaN
# 38                                  [Kızılay, Ankara]        NaN
# 39                                                NaN        NaN
# 40                                                NaN        NaN
# 41                                            [06420]      06420
# 42                                                NaN        NaN
# 43                                                NaN        NaN
# 44                                                NaN        NaN
# 45                                                NaN        NaN
# 46                                                NaN        NaN
# 47                                                NaN        NaN
# 48                                           [Ankara]        NaN
# 49                                                NaN        NaN
#
#            crossStreet                        id
# 0                  NaN  5498847e498e8683bf335cba
# 1                  NaN  4fec4b22e4b0044db3f03d9a
# 2                  NaN  54395353498e6f51e69dae43
# 3                  NaN  50ce209de4b044fa5bdb1681
# 4             ulus cad  5ace189a6adbf52451461053
# 5                  NaN  4d9f08278ef3a143bf428910
# 6                  NaN  4e3989ca18a8d2fcc62ce92a
# 7                  NaN  53cd2e30498e6baf0b1b4f4a
# 8         Tunalı Hilmi  5144ba66e4b0853bebbba20b
# 9                  NaN  5c559f1da9e402002ce043f8
# 10                 NaN  56bf6169498e0190cd31ddc6
# 11     Atatürk Bulvarı  56f408a7498e3933d7c255b9
# 12                 NaN  4c7556dbb474a1cdacf9b8bf
# 13                 NaN  4fa97010e4b04afbc0e3c84d
# 14                 NaN  57ce7fbb498e4c597b09d24a
# 15     Sakarya Caddesi  5e4e311578303e000871acb4
# 16                 NaN  521b772611d29cbfea4567b0
# 17                 NaN  5152cbaae4b0659b3119609b
# 18                 NaN  5040c327e4b06be18f8c08f5
# 19                 NaN  4fc8d366e4b04ec64b1cbdcd
# 20     Atatürk Bulvarı  53581634498eca0421fc4625
# 21                 NaN  56d6d90d498ef2bd01c0aefc
# 22                 NaN  577d1551498e4a16c8a927d0
# 23                25/4  512f2eece4b0c636267e75ef
# 24                 NaN  51629160e4b00ea019853286
# 25                 NaN  51d4628e498e7eba71e572e7
# 26                 NaN  514f4f64e4b03149222f44d7
# 27                 NaN  5980b9e81fa7630c41df5c71
# 28        Cemal Gürsel  51e17fae8bbd74f34b602ede
# 29                 NaN  528b6973498e5c7b36358756
# 30                 NaN  53f4c986498e94d155ce525f
# 31                 NaN  51c1aceb498e2bd1db31a162
# 32                 NaN  514f055be4b031491f3fbfcd
# 33                 NaN  4e3af6d97d8b90abc32d5691
# 34                 NaN  53b15e0b498e5522d455b5a2
# 35  Meşrutiyet caddesi  57c2db02498e960e0b79ee0d
# 36                 NaN  53d8f190498ef67568454c97
# 37                 NaN  56c183c5cd10bb645fa79d75
# 38                 NaN  5310980611d2961d7baf3f0d
# 39                 NaN  56dc84a0cd108a3947a6f810
# 40                 NaN  51124de1e4b05bd664cf43e9
# 41                 NaN  5a59e5c6c66666463e20ffb1
# 42                 NaN  53482964498e9b8b62ba4c18
# 43                 NaN  543bfcf3498e0a3393ce325d
# 44                 NaN  53c430a5498e3b5ccb0d9b02
# 45                 NaN  5636eb82498ef83084af5773
# 46                 NaN  5220c9ed11d287f1222b9229
# 47                 NaN  576fe805498e2794c1a58b40
# 48                 NaN  53c2bbcd498e8361723ec01f
# 49                 NaN  55dddc4c498ef83596813937

# %%
dataframe_filtered.name
# Out:
# 0                                 Karikatür Bi Kafe
# 1                        Kızılay Fal Merkezi & Kafe
# 2     Nazım Hikmet Kültür Merkezi Şair Kafe Sahnesi
# 3                                        Çınar Kafe
# 4                                      Turuncu Kafe
# 5                                Ayça İnternet Kafe
# 6                              Anıttepe Kafe Market
# 7                                     Kafe Karanfil
# 8                                      Tiyatro Kafe
# 9                                        Pucca Kafe
# 10                                Kızılay PARK KAFE
# 11                                       Mekan Kafe
# 12                                        Ezgi Cafe
# 13                                        Park Kafe
# 14                                        park kafe
# 15                        Limit Kütüphane-Kafe-Kurs
# 16                               Kızılay Tarot Kafe
# 17                                      Gülçin Kafe
# 18                                      Kafe Kanape
# 19                                       Tabut Kafe
# 20                                 ortaköy kafe bar
# 21                                       altın kafe
# 22                                      Karaca Kafe
# 23      Kafe Karamel kahve falinda bir numara LEYLA
# 24                                      Kültür Kafe
# 25                                       Asyam Kafe
# 26                                        Döpi Kafe
# 27                                       Simit Kafe
# 28                           Kardelen İnternet Kafe
# 29                                       Sevgi Kafe
# 30                             Mülkiye Gençlik Kafe
# 31                                    Kafe 'D' Keyf
# 32                                       Özgür Kafe
# 33                               Art Kafe & Çay Evi
# 34                                          İn Kafe
# 35                                       Uzman Kafe
# 36                                           T-Kafe
# 37                                       Çevik Kafe
# 38                                 Mekan Kitap Kafe
# 39                                         Sem Kafe
# 40                                    Alaturka kafe
# 41                                          +1 Kafe
# 42                                   Türkü kafe pub
# 43                                       ladus kafe
# 44                        Çaldıran Kafe-Oyun Salonu
# 45                              Fırıncım teras kafe
# 46                            kapi7 kafe restaurant
# 47                                         Ada Kafe
# 48                                        Gazi Kafe
# 49                                        Ezgi Kafe
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_85da71718f084624965043bf6b1e1735%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_85da71718f084624965043bf6b1e1735%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_85da71718f084624965043bf6b1e1735%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_85da71718f084624965043bf6b1e1735%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.9207486%2C%2032.8540093%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
from spylon_kernel import register_ipython_magics
register_ipython_magics()

# %%
# %%scala
# val x = 8
# x
# Out:
# Intitializing Scala interpreter ...
# Spark Web UI available at http://192.168.0.15:4040
# SparkContext available as 'sc' (version = 3.0.1, master = local[*], app id = local-1615667393124)
# SparkSession available as 'spark'

# %%
# %%scala
# val x = 2
# val y = 3
# x*y
